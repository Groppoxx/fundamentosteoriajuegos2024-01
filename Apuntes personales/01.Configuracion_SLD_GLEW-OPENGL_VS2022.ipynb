# %% [markdown]
# # Configuración de SDL y GLEW-OPENGL en Visual Studio 2022

# %% [markdown]
# ## 1. Preparando los archivos

# %% [markdown]
# ### 1.1 Descargando SDL

# %% [markdown]
# * Ingresamos a la pagina de SDL:

# %% [markdown]
# >

# %% [markdown]
# > https://www.libsdl.org/

# %% [markdown]
# * Damos click en la esquina superior derecha:

# %% [markdown]
# ![Screenshot 2024-04-08 003657.png](attachment:eb7195fa-e636-4f45-809b-f0c757ff1b44.png)

# %% [markdown]
# * Descargamos y descomprimimos los siguientes archivos:

# %% [markdown]
# ![Screenshot 2024-04-08 004111.png](attachment:7b22902e-4a02-48ca-a87a-55e2c4bb68b4.png)

# %% [markdown]
# ### 1.2 Descangando GLEW-OPENGL

# %% [markdown]
# * Ingresamos a la pagina de GLEW-OPENGL:

# %% [markdown]
# > https://glew.sourceforge.net/

# %% [markdown]
# * Descargamos y descomprimimos los siguientes archivos:

# %% [markdown]
# ![Screenshot 2024-04-08 004544.png](attachment:ccf355f4-ee79-4168-87c7-d007af8f1054.png)

# %% [markdown]
# ### 1.3 Descargando EGL:

# %% [markdown]
# * Ingresamos al repositorio en GitHub de KhronosGroup:

# %% [markdown]
# > https://github.com/KhronosGroup/EGL-Registry/blob/main/api/EGL/eglplatform.h

# %% [markdown]
# * Descargamos el archivo **eglplatform.h**

# %% [markdown]
# ###  1.4 Descargando EGL:

# %% [markdown]
# * Ingresamos al repositorio en GitHub de KhronosGroup:

# %% [markdown]
# > https://github.com/KhronosGroup/EGL-Registry/blob/main/api/KHR/khrplatform.h

# %% [markdown]
# * Descargamos el archivo khrplatform.h

# %% [markdown]
# ## 2. Creando el proyecto

# %% [markdown]
# * Creamos un nuevo proyecto vacio en VS2020:

# %% [markdown]
# ![Screenshot 2024-04-08 005236.png](attachment:f971810d-f710-4a0c-9439-947a2319a6d7.png)

# %% [markdown]
# * Probamos que el proyecto se haya creado correctamente:

# %% [markdown]
# <pre>#include < iostream >
# using namespace std;
#
# int main() {
# 	cout << "Hello World!\n";
#
# 	system("pause");
# 	return 0;
# }
# </pre>

# %% [markdown]
# ![image.png](attachment:49bb8230-4693-4144-90e6-67fc0a4c1404.png)

# %% [markdown]
# ## 3. Configurando el entorno

# %% [markdown]
# ### 3.1 Creando carpetas

# %% [markdown]
# * Ingresamos a la ubicacion del proyecto:

# %% [markdown]
# > C:\Users\Ian\source\repos\Prueba

# %% [markdown]
# * Creamos una carpeta **depts**:

# %% [markdown]
# ![Screenshot 2024-04-08 201445.png](attachment:55cdc892-e491-479e-aea3-4432651a33b0.png)

# %% [markdown]
# * Dentro de la carpeta creada, creamos 2 carpetas **include** y **lib**:

# %% [markdown]
# ![image.png](attachment:05c18c55-c5c7-44a0-8200-707c1dd996f2.png)

# %% [markdown]
# * Dentro de la carpeta **include** creamos 4 carpetas **EGL**, **GL**, **KHR** y **SDL**:

# %% [markdown]
# ![image.png](attachment:7c18d8e2-369a-4623-9ff8-a39a74824dd7.png)

# %% [markdown]
# ### 3.2 Trasladando archivos

# %% [markdown]
# * Luego de preparar los archivos (**1. Preparando los archivos**), deberiamos tener:

# %% [markdown]
# ![image.png](attachment:269ceceb-85a6-4b5a-ac24-87f14428f13a.png)

# %% [markdown]
# #### 3.2.1 Para la carpeta "include"

# %% [markdown]
# ##### 3.2.1.1 Para EGL

# %% [markdown]
# * Copiareamos el archivo **eglplatform.h** y lo trasladaremos a la carpeta **EGL**

# %% [markdown]
# ##### 3.2.1.2 Para KHR

# %% [markdown]
# * Copiaremos el archivo **khrplatform.h** y lo trasladaremos a la carpeta **KHR**

# %% [markdown]
# ##### 3.2.1.3 Para GL

# %% [markdown]
# * Ingresamos a la carpeta **glew-2.1.0-win32**

# %% [markdown]
# * Ingresamos a la carpeta **glew-2.1.0**

# %% [markdown]
# * Ingresamos a la carpeta **include**

# %% [markdown]
# * Ingresamos a la carpeta **GL**

# %% [markdown]
# * Copiaremos todos los archivos y lo trasladaremos a la carpeta **GL**

# %% [markdown]
# ![image.png](attachment:87c2ff79-a24c-44ff-a4ca-98e466bbe526.png)

# %% [markdown]
# ##### 3.2.1.4 Para SDL

# %% [markdown]
# * Ingresamos a la carpeta **SDL2-devel-2.30.2-VC**

# %% [markdown]
# * Ingresamos a la carpeta **SDL2-2.30.2**

# %% [markdown]
# * Ingresamos a la carpeta **include**

# %% [markdown]
# * Copiaremos todos los archivos y lo trasladaremos a la carpeta SDL

# %% [markdown]
# ![image.png](attachment:5fc64f71-8a64-4373-bb4e-bbcbc1560b2e.png)

# %% [markdown]
# #### 3.2.2 Para la carpeta "lib"

# %% [markdown]
# ##### 3.2.2.1 Para los archivos de GLEW-OPENGL

# %% [markdown]
# * Realizaremos los pasos del punto **3.2.1.3** hasta el ingreso a la carpeta **glew-2.1.0**

# %% [markdown]
# * Ingresamos a la carpeta **lib**

# %% [markdown]
# * Ingresamos a la carpeta **Release**

# %% [markdown]
# * Ingresamos a la carpeta **x64**

# %% [markdown]
# * Copiaremos todos los archivos y lo trasladaremos a la carpeta **lib**

# %% [markdown]
# ![image.png](attachment:3d163873-c8af-473f-9492-82e0d770a55c.png)

# %% [markdown]
# ##### 3.2.2.2 Para los archivos de SDL

# %% [markdown]
# * Realizaremos los pasos del punto **3.2.1.4** hasta el ingreso a la carpeta **SDL2-2.30.2**

# %% [markdown]
# * Ingresamos a la carpeta **lib**

# %% [markdown]
# * Ingresamos a la carpeta **x64**

# %% [markdown]
# * Copiaremos todos los archivos **.lib** y lo trasladaremos a la carpeta **lib**

# %% [markdown]
# ![Screenshot 2024-04-08 205406.png](attachment:26c870de-3fe9-4890-b13e-6430b86b33dc.png)

# %% [markdown]
# #### 3.2.3 Para la carpeta "x64"

# %% [markdown]
# * En la ubicacion de nuestro proyecto ingresaremos a la carpeta **x64**

# %% [markdown]
# ![Screenshot 2024-04-08 210747.png](attachment:6fe54275-f6cb-4316-8a58-41391432f0b8.png)

# %% [markdown]
# * Ingresamos a la carpeta **Debug**

# %% [markdown]
# ##### 3.2.3.1 En la carpeta "glew-2.1.0-win32"

# %% [markdown]
# * Realizaremos los pasos del punto 3.2.1.3 hasta el ingreso a la carpeta glew-2.1.0

# %% [markdown]
# * Ingresamos a la carpeta **bin**

# %% [markdown]
# * Ingresamos a la carpeta **Release**

# %% [markdown]
# * Ingresamos a la carpeta **x64**

# %% [markdown]
# * Copiaremos el archivo **.dll** y lo trasladaremos a la carpeta **Debug**

# %% [markdown]
# ![Screenshot 2024-04-08 211658.png](attachment:b0049f3a-b81c-45eb-98ca-0bd5b17b0b7b.png)

# %% [markdown]
# ##### 3.2.3.2 En la carpeta "SDL2-2.30.2-win32-x64"

# %% [markdown]
# * Copiaremos el archivo **.dll** y lo trasladaremos a la carpeta **Debug**

# %% [markdown]
# ![Screenshot 2024-04-08 211936.png](attachment:c1fffe3b-73a4-40fd-ba43-9ae13b8ed08c.png)

# %% [markdown]
# ## 4. Configurando las propiedades

# %% [markdown]
# * Dentro de nuestro proyecto

# %% [markdown]
# * Ingresamos a **Properties** en el apartado de **Project**

# %% [markdown]
# ![project-properties.gif](attachment:f631c504-5b2f-45cc-bc5f-143457822828.gif)

# %% [markdown]
# * Damos click en el apartado de **VC++ Directories**

# %% [markdown]
# * En **General** damos damos click en **Include Directories** y pegamos:

# %% [markdown]
# <pre> $(SolutionDir)depts/include/;$(IncludePath) </pre>

# %% [markdown]
# * En **General** damos damos click en **Library Directories** y pegamos:

# %% [markdown]
# <pre> $(SolutionDir)depts/lib/;$(LibraryPath) </pre>

# %% [markdown]
# * Damos click en el apartado de **Linker** y luego a **Input**

# %% [markdown]
# * En **Additional Dependencies** damos click y pegamos:

# %% [markdown]
# <pre> glew32.lib;glew32s.lib;SDL2.lib;SDL2main.lib;SDL2test.lib;opengl32.lib;%(AdditionalDependencies) </pre>

# %% [markdown]
# ![change-properties.gif](attachment:3f75c740-5178-4182-9b8b-88a0f8aa60f1.gif)

# %% [markdown]
# * Ejecutamos el proyecto con el siguiente codigo:

# %% [markdown]
# <pre>#include < iostream >
# #include < SDL/SDL.h >
# using namespace std;
#
# int main(int argc, char** argv) {
# 	cout << "Hello World!\n";
#
# 	system("pause");
# 	return 0;
# }
# </pre>
